# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# <!-- This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing -->
#
# - Lola Wang: Data ethics, Data cleaning, Dataset description, Analysis
# - Adrienne Riley: Research question and hypothesis, Data cleaning, Dataset overview, Analysis
# - Sharon Kodali: Writing – review & editing, Data cleaning, Analysis
# - Summer Garvais: Background research, Data cleaning, Dataset description, Analysis
# - Kai Arizabal: Conceptualization (Data), Data cleaning, Dataset description, Analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there an association between increased ridership at San Diego Trolley stations and nearby crime rates over time? Are these effects different across neighborhood socioeconomic contexts?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Many people argue against the implementation of public transportation in their neighborhoods, citing its tendency to bring crime into their communities. But is this really true? Much research has been done looking into the relationship between public transportation and crime rates and different conclusions have been drawn. Some claim that public transportation can “import” crime into wealthy neighborhoods, leading to higher than normal crime rates. Others see this crime “import” effect as unconvincing, and instead find public transportation alleviates socioeconomic stressors which provoke people into doing crime in the first place.
#
# An issue presented when studying public transportation, particularly discerning its impact on crime rates, is the seeming lack of A/B testing. A place that has access to public transportation and one that doesn’t cannot typically be tested against each other without accounting for a multitude of external factors. This makes sense because many things contribute to whether or not a place is given the opportunity to have public transportation or not. In a clever attempt to navigate this issue, David C. Phillips and Danielle Sandler<a name="cite_note-1"></a> [^](#cite_ref-1) wrote a paper analyzing crime rates in the Washington D.C. area when certain transit stations were closed. The paper found that crime decreases across the railway network when stations are closed and that the decrease in crime was felt more in areas where fewer offenders lived. In essence, the closure of stations can inhibit how easily criminals can navigate the network.
#
# Another project, completed by Greg Ridgeway and John MacDonald, looked more holistically at the railway network in Los Angeles over a 27 year span from 1988-2014.<a name="cite_note-2"></a> [^](#cite_ref-2) They conclude that there is little evidence that access to public railways lead to an increase in crime in neighborhoods. While they do concede that criminals could use railways to travel to lower crime, wealthy areas to find victims, they argue that access to public transportation could lower overall crime rates in a metropolitan area. They claim that giving public transit access to people who hail from low socioeconomic areas can help them seek better opportunities rather than resort to crime.
#
# Looking through the lens of public safety, Tanya Lewis writes an article detailing how public transportation results in far fewer deaths and fewer crimes than automobile travel. <a name="cite_note-3"></a> [^](#cite_ref-3) Per 1 billion passenger miles traveled in 2022, automobiles caused 16.8 fatalities in rural areas and 11.5 in urban areas. To contrast, rail transit fatalities were 5.9 per 1 billion miles and many were non-occupant fatalities that resulted from suicide. Additionally, crimes like assault, robbery, and homicide are down on public transportation in 2023 compared to in 2019 while motor vehicle theft and road rage incidents involving guns are up. The article suggests that many people feel more unsafe on public transportation than they should according to the statistics.
#
# Diving deeper into this phenomenon, Anastasia Loukaitou-Sideris and Camille Fink address the fear women feel when using public transportation.<a name="cite_note-4"></a> [^](#cite_ref-4) Women will often avoid certain railways, only use them in the day, or forego public transportation altogether due to fear of victimization. According to Loukaitou-Sideris and Fink, much of this blame should be put into the lack of input women get when designing safety procedures for public transportation. Citing the lack of security, cameras, panic buttons, or other bystanders who could help, the authors argue that women will continue to avoid public transportation so long as there is no greater attempt to prevent crime around transportation infrastructure like bus stops, trains etc. If public transportation does in fact have a way of bringing crime to certain areas, increased security around transit stops could potentially help to mitigate this.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Phillips, David C., and Danielle Sandler. “Does Public Transit Spread Crime? Evidence from Temporary Rail Station Closures.” Regional Science and Urban Economics, vol. 52, 2015, pp. 13–26, https://doi.org/10.1016/j.regsciurbeco.2015.02.001
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2)Ridgeway, Greg, and John M. MacDonald. Effect of Rail Transit on Crime: A Study of Los Angeles from 1988–2014. Department of Criminology Working Paper No. 2015-14.0, University of Pennsylvania, 2015, crim.sas.upenn.edu/sites/default/files/2015-14.0_Ridgeway_MacDonald_RailEffect%281%29.pdf.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)Lewis, Tanya. “Is Public Transit Really Safer Than Driving?” Scientific American, 15 Apr. 2025, www.scientificamerican.com/article/is-public-transit-really-safer-than-driving/
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Loukaitou-Sideris, Anastasia, and Camille Fink. “Addressing Women’s Fear of Victimization in Transportation Settings: A Survey of U.S. Transit Agencies.” Urban Affairs Review, vol. 44, no. 4, 2008, pp. 554–587, https://doi.org/10.1177/1078087408322874

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that the relationship between San Diego Trolley ridership and nearby crime rates over time will be weak or mixed, rather than uniformly positive or negative. This is because we expect that any observed differences in crime patterns will be driven largely by preexisting neighborhood socioeconomic conditions, rather than the transit use itself. This aligns with prior research suggesting public transit is often blamed for crime patterns that reflect broader structural inequities rather than transit use.
#
# Null Hypothesis: Changes in San Diego Trolley ridership have no association with nearby crime rates over time.
#
# Alternative Hypothesis: Any association between trolley ridership and crime varies across neighborhoods and is more strongly related to socioeconomic context than to ridership levels alone.

# %% [markdown]
# ### Setup

# %%
import os
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.formula.api as smf
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: Transit Stops Data
#   - Link to the dataset:
#      csv file: https://raw.githubusercontent.com/COGS108/Group022_WI26/refs/heads/master/data/00-raw/transit_stops_datasd.csv
#   found on: https://data.sandiego.gov/datasets/transit-stops/
#   - Number of observations: 6220
#   - Number of variables: 14
#   - Variables most relevant to this project:
#   The most relevant variables in this dataset are stop_name, stop_lat, and stop_lon. These provide the geographic location of each transit stop. These latitude and longitude coordinates allow us to map stop locations and consider spatial patterns across San Diego. The stop_id and stop_code uniquely identify each transit stop and might be helpful for potential merging with other transit-related datasets.
#   - Shortcomings of this dataset:
#     This data set has strictly static information and does not include ridership data, service frequency, route information, demographic/socioeconomic context, or temporal variables. Because of this, it cannot directly measure usage patterns or equity without being combined with additional datasets.
# - Dataset #2
#   - Dataset Name: 2025 Crime Rates Data
#   - Link to the dataset:
#      pdf file: https://www.sandiego.gov/sites/default/files/2026-02/nibrs-crime-rates-per-1000-residents-2025.pdf
#      (tables extracted and stored locally in data/00-raw/)
#   - Number of observations: 124
#   - Number of variables: 23
#   - Variables most relevant to this project:
#     The most relevant variable is Neighborhood, which serves as the spatial identifier and merge key across datasets. Crime rate variables such as Simple Assault, Intimidation, Robbery, Larceny, Theft From Motor Vehicle, Motor Vehicle Theft, Vandalism, and Drug/Narcotic Violations are particularly relevant because these categories are commonly associated with public transit corridors. All crime values are reported as rates per 1,000 residents, allowing standardized comparison across neighborhoods of different population sizes.
#   - Shortcomings of this dataset:
#     This dataset has no temporal granularity and only basic spatial granularity. Crime is aggregated at the neighborhood level, meaning we do not have specific coordinates, addresses, or timestamps for individual incidents. Because the data is cross-sectional (single year: 2025), it does not allow trend analysis over time. The aggregated structure limits our ability to infer causal relationships between trolley access and crime. Additionally, the official data was provided in PDF format and required extraction into CSV before analysis. During cleaning, we identified a minor neighborhood name inconsistency (`SOUTHCRES T` vs. `SOUTHCREST`) that initially caused one neighborhood to be excluded during merging; this was corrected to ensure all 125 neighborhoods aligned properly across datasets.
# - Dataset #3
#   - Dataset Name: 2023-2025 Trolley Ridership Data
#   - Link to the dataset: https://docs.google.com/spreadsheets/d/1cPsb79L0UxOO0RKK9ocRqt0266YbLu3t/edit?usp=sharing&ouid=106177930174269265857&rtpof=true&sd=true (Data exported as .csv and imported to data/00-raw/)
#   - Number of observations: 480
#   - Number of variables: 6
#   - Variables most relevant to this project: The most relevant variables are `Ridership` (average weekday boardings per station), `Station` (trolley stop name), `Year`, and `Neighborhood` (stop location by police reporting zone). `Station` and `Neighborhood` enable us to join this dataset with others. `Ridership` and `Year` allow for direct analysis of the relationship between trolley services and crime in San Diego.
#   - Shortcomings of this dataset: The most significant shortcoming of this dataset is the temporal resolution. Although it suggests that this includes 2025 ridership information, the dataset only contains data from January, 1 2025 through January 26, 2025. There are temporal inaccuracies between the datasets and within the data. We must assume that this information is a good proxy for 2025.
# - Dataset #4
#   - Dataset Name: Equity Report Demographics
#   - Link to the dataset: https://docs.google.com/spreadsheets/d/1d4Es0GfsRlOWw9pfHYrPDC-PorCLNJIV/edit?usp=sharing&ouid=111624295336400465653&rtpof=true&sd=true
#   - Number of observations: 3222
#   - Number of variables: 15
#   - Variables most relevant to this project: The variable that are relevant to our project refer to the time the data was recorded, and qualities of the groups being recorded. Thus, the variables we will focus on are: `equity_report_year`, `data_year`, `indicator`, `data_source`, `group`, `category`, `subcategory`, `count`, `percent`, `rate`
#   - Shortcomings of this dataset: This dataset falls short with temporal inconsistencies and lack of spatial granularity. The data spans differing time periods: the equity report itself covers years 2023-2025, while the underlying data ranges from 2015-2023, creating some temporal misalignment with other project datasets. Additionally, the dataset is aggregated at broad geographic scales with no specific latitude/longitude coordinates, making spatial merging with the crime and trolley ridership data challenging. The dataset's multi-indicator structure means that any individual indicator covers smaller subset of observations, which can limit analysis when it comes to combining datasets. Additionally, the diversity of data sources and potential collection methods draws concerns about consistency and comparability across indicators.
#
#
# <!-- If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets. -->
#
# <!-- We can combine, or at least cross-reference, the datasets based on location. We can do so by using the geographic data from Dataset #1 and identifying which neighborhood each transit stop is located in. -->

# %% [markdown]
# ### Dataset Cleaning
# Because we have multiple datasets that require lots of cleaning before merging together, we will leave this out of the final report. To see the code responsible for wrangling our data from "raw" to "processed" please refer to the previous `02-DataCheckpoint` to follow our cleaning process in depth.

# %% [markdown]
# ### Combining Datasets
# In this section, we will combine the datasets we cleaned from previous checkpoints. Each of our datasets are formatted quite differently and depict widely different data. Thus, the merging process will be a bit clunky and will require some reformatting to allow everything to fit together nicely. The end goal is to have one dataset which details transit stops, their location, their ridership, and nearby crime rates from each year between 2023-2025.

# %% [markdown]
# First, we will take our crime data from the years 2023, 2024, and 2025 and merge those together into one crime dataset, sorted by neighborhood and year.

# %%
crime_df_2023 = pd.read_csv('data/02-processed/clean_nibrs_crime_rates_2023.csv')
crime_df_2024 = pd.read_csv('data/02-processed/clean_nibrs_crime_rates_2024.csv')
crime_df_2025 = pd.read_csv('data/02-processed/clean_nibrs_crime_rates_2025.csv')

# %%
# Add a year column to all datasets
crime_df_2023['Year'] = [2023] * crime_df_2023.shape[0]
crime_df_2024['Year'] = [2024] * crime_df_2024.shape[0]
crime_df_2025['Year'] = [2025] * crime_df_2025.shape[0]

# %%
# Add all crime datasets together
crime_df = pd.concat([crime_df_2023, crime_df_2024, crime_df_2025])
crime_df
# Out:
#               Neighborhood  Homicide  Kidnapping/Abduction  Sexual Assault  \
# 0              ADAMS NORTH       0.0                  0.00            0.00
# 1           ALLIED GARDENS       0.0                  0.10            0.10
# 2               ALTA VISTA       0.0                  0.00            0.00
# 3    AZALEA/HOLLYWOOD PARK       0.0                  0.00            0.60
# 4              BALBOA PARK       0.0                  4.30           14.90
# ..                     ...       ...                   ...             ...
# 120        TORREY PRESERVE       0.0                  0.00            0.00
# 121        UNIVERSITY CITY       0.0                  0.04            0.33
# 122     UNIVERSITY HEIGHTS       0.0                  0.20            0.13
# 123          VALENCIA PARK       0.0                  0.00            0.53
# 124            WOODED AREA       0.0                  0.00            0.00
#
#      Aggravated Assault  Simple Assault  Intimidation  Other Sex Offenses  \
# 0                  1.50            3.00          0.30                0.00
# 1                  1.10            2.60          0.10                0.00
# 2                  1.10            3.30          0.40                0.00
# 3                  3.00            7.30          0.30                0.30
# 4                 51.20           89.60         10.70                0.00
# ..                  ...             ...           ...                 ...
# 120                0.00            0.00          0.00                0.00
# 121                0.81            2.22          0.28                0.04
# 122                1.58            3.22          0.20                0.00
# 123                4.68            5.11          1.06                0.00
# 124                1.14            1.43          0.00                0.00
#
#      Robbery  Arson  ...  Fraud/Counterfeiting  Stolen Property Offenses  \
# 0       0.50   0.00  ...                  1.50                      0.30
# 1       0.00   0.10  ...                  1.30                      0.80
# 2       0.00   0.00  ...                  0.70                      0.00
# 3       0.90   0.30  ...                  3.00                      1.50
# 4      19.20   2.10  ...                  2.10                      6.40
# ..       ...    ...  ...                   ...                       ...
# 120     0.00   0.00  ...                  0.00                      0.00
# 121     0.55   0.02  ...                  2.11                      0.12
# 122     0.13   0.07  ...                  2.04                      0.33
# 123     0.32   0.00  ...                  1.17                      0.21
# 124     0.00   0.00  ...                  1.72                      0.29
#
#      Vandalism  Drug/Narcotic Offenses  Pornography/Obscene Material  \
# 0         4.70                    1.70                          0.00
# 1         2.60                    1.10                          0.00
# 2         1.90                    0.40                          0.00
# 3         4.00                    3.40                          0.00
# 4        74.60                   89.60                          0.00
# ..         ...                     ...                           ...
# 120       0.00                    0.00                          0.00
# 121       2.36                    0.70                          0.02
# 122       3.48                    2.30                          0.00
# 123       3.30                    1.60                          0.00
# 124       0.86                    1.14                          0.00
#
#      Gambling Offenses  Prostitution  Weapon Law Violations  Animal Cruelty  \
# 0                  0.0          0.00                   0.30             0.2
# 1                  0.0          0.00                   0.30             0.0
# 2                  0.0          0.00                   0.00             0.0
# 3                  0.3          0.00                   2.40             0.0
# 4                  0.0          0.00                   2.10             0.0
# ..                 ...           ...                    ...             ...
# 120                0.0          0.00                   0.00             0.0
# 121                0.0          0.00                   0.05             0.0
# 122                0.0          0.07                   0.33             0.0
# 123                0.0          0.00                   0.53             0.0
# 124                0.0          0.00                   0.00             0.0
#
#      Year
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# ..    ...
# 120  2025
# 121  2025
# 122  2025
# 123  2025
# 124  2025
#
# [375 rows x 24 columns]

# %%
# Now we can see how the crime rates changed in each neighborhood for each year
neighborhood_crime_df = crime_df.groupby(['Neighborhood', 'Year']).sum()
neighborhood_crime_df
# Out:
#                      Homicide  Kidnapping/Abduction  Sexual Assault  \
# Neighborhood   Year
# ADAMS NORTH    2023       0.0                  0.00            0.00
#                2024       0.0                  0.20            0.20
#                2025       0.0                  0.33            0.50
# ALLIED GARDENS 2023       0.0                  0.10            0.10
#                2024       0.0                  0.10            0.20
# ...                       ...                   ...             ...
# VALENCIA PARK  2024       0.0                  0.00            0.40
#                2025       0.0                  0.00            0.53
# WOODED AREA    2023       0.0                  0.00            0.30
#                2024       0.0                  0.00            0.00
#                2025       0.0                  0.00            0.00
#
#                      Aggravated Assault  Simple Assault  Intimidation  \
# Neighborhood   Year
# ADAMS NORTH    2023                1.50            3.00          0.30
#                2024                1.20            2.30          0.00
#                2025                0.66            1.49          0.00
# ALLIED GARDENS 2023                1.10            2.60          0.10
#                2024                1.20            2.30          0.40
# ...                                 ...             ...           ...
# VALENCIA PARK  2024                5.60            6.70          0.60
#                2025                4.68            5.11          1.06
# WOODED AREA    2023                0.00            0.30          0.00
#                2024                0.00            0.00          0.60
#                2025                1.14            1.43          0.00
#
#                      Other Sex Offenses  Robbery  Arson  \
# Neighborhood   Year
# ADAMS NORTH    2023                 0.0     0.50   0.00
#                2024                 0.0     0.70   0.00
#                2025                 0.0     0.33   0.17
# ALLIED GARDENS 2023                 0.0     0.00   0.10
#                2024                 0.0     0.30   0.00
# ...                                 ...      ...    ...
# VALENCIA PARK  2024                 0.0     0.50   0.00
#                2025                 0.0     0.32   0.00
# WOODED AREA    2023                 0.0     0.00   0.00
#                2024                 0.0     0.00   0.00
#                2025                 0.0     0.00   0.00
#
#                      Burglary/Breaking & Entering  ...  Motor Vehicle Theft  \
# Neighborhood   Year                                ...
# ADAMS NORTH    2023                          2.20  ...                 2.70
#                2024                          1.20  ...                 2.70
#                2025                          1.00  ...                 1.00
# ALLIED GARDENS 2023                          1.20  ...                 2.00
#                2024                          1.50  ...                 2.30
# ...                                           ...  ...                  ...
# VALENCIA PARK  2024                          0.50  ...                 3.60
#                2025                          0.96  ...                 1.49
# WOODED AREA    2023                          0.30  ...                 1.40
#                2024                          1.40  ...                 1.70
#                2025                          0.57  ...                 0.57
#
#                      Fraud/Counterfeiting  Stolen Property Offenses  \
# Neighborhood   Year
# ADAMS NORTH    2023                  1.50                      0.30
#                2024                  1.30                      0.50
#                2025                  1.99                      0.17
# ALLIED GARDENS 2023                  1.30                      0.80
#                2024                  1.50                      0.20
# ...                                   ...                       ...
# VALENCIA PARK  2024                  1.40                      0.30
#                2025                  1.17                      0.21
# WOODED AREA    2023                  0.30                      0.00
#                2024                  2.00                      0.30
#                2025                  1.72                      0.29
#
#                      Vandalism  Drug/Narcotic Offenses  \
# Neighborhood   Year
# ADAMS NORTH    2023       4.70                    1.70
#                2024       3.70                    0.30
#                2025       2.16                    0.83
# ALLIED GARDENS 2023       2.60                    1.10
#                2024       2.50                    1.40
# ...                        ...                     ...
# VALENCIA PARK  2024       3.50                    2.90
#                2025       3.30                    1.60
# WOODED AREA    2023       1.70                    0.00
#                2024       1.10                    1.10
#                2025       0.86                    1.14
#
#                      Pornography/Obscene Material  Gambling Offenses  \
# Neighborhood   Year
# ADAMS NORTH    2023                           0.0                0.0
#                2024                           0.0                0.0
#                2025                           0.0                0.0
# ALLIED GARDENS 2023                           0.0                0.0
#                2024                           0.0                0.0
# ...                                           ...                ...
# VALENCIA PARK  2024                           0.0                0.0
#                2025                           0.0                0.0
# WOODED AREA    2023                           0.0                0.0
#                2024                           0.0                0.0
#                2025                           0.0                0.0
#
#                      Prostitution  Weapon Law Violations  Animal Cruelty
# Neighborhood   Year
# ADAMS NORTH    2023           0.0                   0.30             0.2
#                2024           0.0                   0.50             0.0
#                2025           0.0                   0.50             0.0
# ALLIED GARDENS 2023           0.0                   0.30             0.0
#                2024           0.0                   0.40             0.0
# ...                           ...                    ...             ...
# VALENCIA PARK  2024           0.0                   1.30             0.0
#                2025           0.0                   0.53             0.0
# WOODED AREA    2023           0.0                   0.00             0.0
#                2024           0.0                   0.00             0.0
#                2025           0.0                   0.00             0.0
#
# [375 rows x 22 columns]

# %%
# Narrowing the datset to more prevalent, common crimes
selected_cols = [
    "Simple Assault",
    "Robbery",
    "Larceny",
    "Motor Vehicle Theft",
    "Vandalism",
    "Drug/Narcotic Offenses"
]

neighborhood_common_crime_df = neighborhood_crime_df[selected_cols].reset_index()
neighborhood_common_crime_df
# Out:
#        Neighborhood  Year  Simple Assault  Robbery  Larceny  \
# 0       ADAMS NORTH  2023            3.00     0.50     4.00
# 1       ADAMS NORTH  2024            2.30     0.70     5.20
# 2       ADAMS NORTH  2025            1.49     0.33     6.48
# 3    ALLIED GARDENS  2023            2.60     0.00     2.00
# 4    ALLIED GARDENS  2024            2.30     0.30     2.80
# ..              ...   ...             ...      ...      ...
# 370   VALENCIA PARK  2024            6.70     0.50     3.80
# 371   VALENCIA PARK  2025            5.11     0.32     3.09
# 372     WOODED AREA  2023            0.30     0.00     2.00
# 373     WOODED AREA  2024            0.00     0.00     3.40
# 374     WOODED AREA  2025            1.43     0.00     4.29
#
#      Motor Vehicle Theft  Vandalism  Drug/Narcotic Offenses
# 0                   2.70       4.70                    1.70
# 1                   2.70       3.70                    0.30
# 2                   1.00       2.16                    0.83
# 3                   2.00       2.60                    1.10
# 4                   2.30       2.50                    1.40
# ..                   ...        ...                     ...
# 370                 3.60       3.50                    2.90
# 371                 1.49       3.30                    1.60
# 372                 1.40       1.70                    0.00
# 373                 1.70       1.10                    1.10
# 374                 0.57       0.86                    1.14
#
# [375 rows x 8 columns]

# %%
folder_name = os.path.join('data', '02-processed')
file_name = f'clean_neighborhood_common_crime_rates.csv'
full_path = os.path.join(folder_name, file_name)
os.makedirs(folder_name, exist_ok=True)
neighborhood_common_crime_df.to_csv(full_path, index=False)
print(f'Data successfully saved to "{full_path}"')
# Out:
# Data successfully saved to "data/02-processed/clean_neighborhood_common_crime_rates.csv"

# %% [markdown]
# ### Merging all datasets
# Now that we have our crime rate dataset all together, we can start merging everything together.

# %%
# Importing all 4 processed datasets

clean_stops_df = pd.read_csv('data/02-processed/clean_transit_stops_datasd.csv')
clean_crime_df = pd.read_csv('data/02-processed/clean_neighborhood_common_crime_rates.csv')
clean_ridership_df = pd.read_csv('data/02-processed/cleaned_mts_trolley_ridership_data.csv')
clean_equity_df = pd.read_csv("data/02-processed/clean_equity.csv")

# %%
# Reformats naming convention of 'Station' in our transit stops data to match that of ridership data

def clean_stops(t):
    output = re.sub(r'[^\w\s]', ' ', t).lower().replace('station', '')
    output = re.sub(r'\bstreet\b|\bst\b', '', output, flags=re.IGNORECASE)
    output = re.sub(r'\bavenue\b|\bave\b', '', output, flags=re.IGNORECASE)
    return re.sub(r'\s+', ' ', output).strip()

# %%
# Creates a new transit stops column following clean station name formatting

clean_ridership_df['stop_join'] = clean_ridership_df['Station'].apply(clean_stops)

clean_stops_df['stop_join'] = np.where(
    (clean_stops_df['stop_id'].str[:2] == '75') | (clean_stops_df['stop_id'].str[:2] == '77'),
    clean_stops_df['stop_name'].apply(clean_stops), 
    np.nan
)

# %%
clean_stops_df.loc[~clean_stops_df['stop_join'].isin(clean_ridership_df['stop_join']), 'stop_join'].unique()
# Out:
# array([nan, 'union grantville', 'santee town center'], dtype=object)

# %%
clean_ridership_df.loc[clean_ridership_df['stop_join'].str.match('santee|grantville'), 'stop_join'].unique()
# Out:
# array(['grantville', 'santee'], dtype=object)

# %%
# Resolves a naming conflict between transit stop and ridership dataset

clean_stops_df['stop_join'] = clean_stops_df['stop_join'].str.replace('santee town center', 'santee').str.replace('union grantville', 'grantville')

# %%
# Groups transit stop data by newly formatted station name and takes mean of each coordinate to resolve any slight discrepancies

clean_stops_df = clean_stops_df.groupby('stop_join').agg({'stop_lat': 'mean', 'stop_lon': 'mean'}).reset_index().round(5)
clean_stops_df.head()
# Out:
#                stop_join  stop_lat   stop_lon
# 0          12th imperial  32.70583 -117.15327
# 1  12th imperial bayside  32.70523 -117.15390
# 2                   24th  32.66183 -117.10801
# 3        25th commercial  32.70528 -117.13994
# 4        32nd commercial  32.70577 -117.12464

# %%
#  Merges transit stop and ridership data on universally formatted station names

transit_crime_df = clean_stops_df.merge(clean_ridership_df, on='stop_join').drop(columns=['stop_join'])
transit_crime_df.head()
# Out:
#    stop_lat   stop_lon        Station  Ridership  Season  Year Neighborhood  \
# 0  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 1  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 2  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 3  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
# 4  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
#
#      Line
# 0    Blue
# 1   Green
# 2  Orange
# 3    Blue
# 4   Green

# %%
# Adds crime data for the neighborhood the transit stop resides in

transit_crime_df = transit_crime_df.merge(clean_crime_df, on=['Neighborhood', 'Year'])
transit_crime_df.head()
# Out:
#    stop_lat   stop_lon        Station  Ridership  Season  Year Neighborhood  \
# 0  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 1  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 2  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 3  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
# 4  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
#
#      Line  Simple Assault  Robbery  Larceny  Motor Vehicle Theft  Vandalism  \
# 0    Blue            64.4     15.5     35.2                  8.4       34.6
# 1   Green            64.4     15.5     35.2                  8.4       34.6
# 2  Orange            64.4     15.5     35.2                  8.4       34.6
# 3    Blue            64.4     15.5     35.2                  8.4       34.6
# 4   Green            64.4     15.5     35.2                  8.4       34.6
#
#    Drug/Narcotic Offenses
# 0                    58.4
# 1                    58.4
# 2                    58.4
# 3                    58.4
# 4                    58.4

# %%
# Since there are many indicators and many subcategories, we will keep a subset of columns to avoid introducing any noise. 
# Additionally, we found that many indicator subcategories have no meaningful shifts in percentage or remained constant over time. 
# Therefore, we priortize categories with measurable shifts and treat those without any shifts as baseline constants.

prevalent_indicators = clean_equity_df['indicator'].unique()
prevalent_cat = clean_equity_df['subcategory'].unique()

prevalent_indicators = clean_equity_df.copy()

prevalent_indicators['indicator_subcategory'] = prevalent_indicators['indicator'] + '_' + prevalent_indicators['subcategory']
equity_pivot_table = prevalent_indicators.pivot_table(index='equity_report_year', columns='indicator_subcategory', values='percent').reset_index()

# %%
# Checking for significant shifts
equity_shifts = equity_pivot_table.iloc[:, 1:].diff().iloc[1]
equity_shifts = equity_shifts[equity_shifts.abs() > 0].sort_values(ascending=False).round(1)
display_n = 10
equity_shifts.name = '2023-2025 Equity Shifts'
pd.concat([equity_shifts[:display_n], equity_shifts[-display_n:]])
# Out:
# indicator_subcategory
# Self-Sufficiency Wage_Yes                                                     25.3
# Self-Sufficiency Wage_No                                                       8.7
# Business Ownership_Minority                                                    3.5
# Commute Time and Method of Transportation_Worked at home                       2.3
# Business Ownership_Hispanic or Latino, of Any Race                             1.8
# English Language Learners_Level 1                                              1.2
# Business Ownership_Female                                                      1.1
# Business Ownership_Asian, Non-Hispanic                                         0.7
# English Language Learners_Level 4                                              0.7
# Business Ownership_Black or African American, Non-Hispanic                     0.5
# Business Ownership_Male                                                       -0.5
# Business Ownership_Equally Female/Male Owned                                  -0.6
# English Language Learners_Level 3                                             -0.7
# English Language Learners_Level 2                                             -1.1
# Commute Time and Method of Transportation_Total Private Motor Vehicle         -2.1
# Commute Time and Method of Transportation_Auto, truck, or van                 -2.2
# Business Ownership_White, Non-Hispanic                                        -2.7
# Commute Time and Method of Transportation_American Indian or Alaska Native    -3.3
# Business Ownership_Nonminority                                                -3.6
# High School Graduates_Some Other Race                                        -50.0
# Name: 2023-2025 Equity Shifts, dtype: float64

# %%
# To guarantee this variable selection is accurate, we check the raw counts of specific indicators to ensure these percent shifts are meaningful rather than data errors. 
# As examples, let's check the highest percent shift and lowest percent shift.

clean_equity_df.loc[(clean_equity_df['indicator'] == 'Self-Sufficiency Wage') & (clean_equity_df['subcategory'] == 'Yes'), ['equity_report_year', 'subcategory', 'count', 'percent']]
# Out:
#       equity_report_year subcategory     count  percent
# 508                 2023         Yes  726356.0     30.3
# 1066                2025         Yes  638240.0     55.6

# %%
clean_equity_df.loc[(clean_equity_df['indicator'] == 'High School Graduates') & (clean_equity_df['subcategory'] == 'Some Other Race'), ['equity_report_year', 'subcategory', 'count', 'percent']]

# The largest negative shift appears to be reporting error.
# Out:
#      equity_report_year      subcategory  count  percent
# 438                2023  Some Other Race  230.0    100.0
# 811                2025  Some Other Race  374.0    100.0
# 812                2025  Some Other Race    0.0      0.0

# %%
# Final selection of equity indicators
equity_pivot_table = equity_pivot_table[[
    'equity_report_year', 'Self-Sufficiency Wage_Yes', 
    'Business Ownership_Minority', 'Commute Time and Method of Transportation_Total Private Motor Vehicle', 
    'English Language Learners_Level 1'
]]
equity_pivot_table.info()
equity_pivot_table.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   equity_report_year                                                     2 non-null      int64
#  1   Self-Sufficiency Wage_Yes                                              2 non-null      float64
#  2   Business Ownership_Minority                                            2 non-null      float64
#  3   Commute Time and Method of Transportation_Total Private Motor Vehicle  2 non-null      float64
#  4   English Language Learners_Level 1                                      2 non-null      float64
# dtypes: float64(4), int64(1)
# memory usage: 212.0 bytes
# indicator_subcategory  equity_report_year  Self-Sufficiency Wage_Yes  \
# 0                                    2023                       30.3
# 1                                    2025                       55.6
#
# indicator_subcategory  Business Ownership_Minority  \
# 0                                        39.133333
# 1                                        42.666667
#
# indicator_subcategory  Commute Time and Method of Transportation_Total Private Motor Vehicle  \
# 0                                                                   80.1
# 1                                                                   78.0
#
# indicator_subcategory  English Language Learners_Level 1
# 0                                              19.585714
# 1                                              20.750000

# %%
# Final merge
df = transit_crime_df.merge(equity_pivot_table, left_on='Year', right_on='equity_report_year').drop(columns=['equity_report_year'])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 18 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   stop_lat                                                               183 non-null    float64
#  1   stop_lon                                                               183 non-null    float64
#  2   Station                                                                183 non-null    object
#  3   Ridership                                                              183 non-null    int64
#  4   Season                                                                 183 non-null    object
#  5   Year                                                                   183 non-null    int64
#  6   Neighborhood                                                           183 non-null    object
#  7   Line                                                                   183 non-null    object
#  8   Simple Assault                                                         183 non-null    float64
#  9   Robbery                                                                183 non-null    float64
#  10  Larceny                                                                183 non-null    float64
#  11  Motor Vehicle Theft                                                    183 non-null    float64
#  12  Vandalism                                                              183 non-null    float64
#  13  Drug/Narcotic Offenses                                                 183 non-null    float64
#  14  Self-Sufficiency Wage_Yes                                              183 non-null    float64
#  15  Business Ownership_Minority                                            183 non-null    float64
#  16  Commute Time and Method of Transportation_Total Private Motor Vehicle  183 non-null    float64
#  17  English Language Learners_Level 1                                      183 non-null    float64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 25.9+ KB
#    stop_lat   stop_lon        Station  Ridership  Season  Year Neighborhood  \
# 0  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 1  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 2  32.70583 -117.15327  12th/Imperial      12936  Summer  2023   PETCO PARK
# 3  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
# 4  32.70583 -117.15327  12th/Imperial      13184    Fall  2023   PETCO PARK
#
#      Line  Simple Assault  Robbery  Larceny  Motor Vehicle Theft  Vandalism  \
# 0    Blue            64.4     15.5     35.2                  8.4       34.6
# 1   Green            64.4     15.5     35.2                  8.4       34.6
# 2  Orange            64.4     15.5     35.2                  8.4       34.6
# 3    Blue            64.4     15.5     35.2                  8.4       34.6
# 4   Green            64.4     15.5     35.2                  8.4       34.6
#
#    Drug/Narcotic Offenses  Self-Sufficiency Wage_Yes  \
# 0                    58.4                       30.3
# 1                    58.4                       30.3
# 2                    58.4                       30.3
# 3                    58.4                       30.3
# 4                    58.4                       30.3
#
#    Business Ownership_Minority  \
# 0                    39.133333
# 1                    39.133333
# 2                    39.133333
# 3                    39.133333
# 4                    39.133333
#
#    Commute Time and Method of Transportation_Total Private Motor Vehicle  \
# 0                                               80.1
# 1                                               80.1
# 2                                               80.1
# 3                                               80.1
# 4                                               80.1
#
#    English Language Learners_Level 1
# 0                          19.585714
# 1                          19.585714
# 2                          19.585714
# 3                          19.585714
# 4                          19.585714

# %%
folder_name = os.path.join('data', '02-processed')
file_name = f'final_transit_crime_data_cleaned.csv'
full_path = os.path.join(folder_name, file_name)
os.makedirs(folder_name, exist_ok=True)
df.to_csv(full_path, index=False)
print(f'Data successfully saved to "{full_path}"')
# Out:
# Data successfully saved to "data/02-processed/final_transit_crime_data_cleaned.csv"

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Now that we have all our datasets cleaned and ready to go, its time to do some data analysis. In this section we will explore correlations between variables, investigate trends, and test probabilities to attempt to answer our research question.
#
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %% [markdown]
# ### Individual Dataset analysis
#
# To start our analysis, we will look at what we can learn from each dataset individually. This will be helpful for making connections with our merged dataset later.

# %% [markdown]
# #### Exploring Transit Stops Across San Diego
#
# This section explores the structure of the San Diego public transit stop dataset. Examining the dataset structure allows us to understand how transit infrastructure is distributed across the region.
#
# We focus on comparing the number of stops operated by the two primary transit agencies in the region: the Metropolitan Transit System (MTS) and the North County Transit District (NCTD). Understanding the distribution of transit stops helps us understand how public transportation access varies geographically and may influence patterns of activity and nearby crime patterns.

# %% [markdown]
# #### Distribution of Transit Stops by Agency

# %%
clean_transit_df = pd.read_csv('data/02-processed/clean_transit_stops_datasd.csv')

cs_f1 = sns.histplot(clean_transit_df, x='stop_agncy')
cs_f1.set_title("Distribution of Transit Stops by Agency")
cs_f1.set_xlabel("Transit Agency")
cs_f1.set_ylabel("Count")
cs_f1
# Out:
# <Axes: title={'center': 'Distribution of Transit Stops by Agency'}, xlabel='Transit Agency', ylabel='Count'>

# %% [markdown]
# This visualization shows the distribution of transit stops by agency across San Diego. The majority of transit stops are operated by the Metropolitan Transit System (MTS) and a smaller portion belong to the North County Transit District (NCTD). This difference reflects the broader service coverage of MTS within the central and southern parts of San Diego County, whereas NCTD primarily operates in northern coastal areas. Understanding the distribution of transit stops by agency helps us better understand how transit infrastructure is organized geographically. This information is also relevant when looking at potential relationships between transit access, ridership patterns, and surrounding urban activity like crime or population density.

# %% [markdown]
# #### Spatial Distribution of Transit Stops Relative to Downtown San Diego

# %%
downtown_sd_lat = 32.7167
downtown_sd_lon = -117.1629

# plot showing proximity to downtown

downtown_stops_df = clean_transit_df.copy()
downtown_stops_df['lat_from_dt'] = downtown_stops_df['stop_lat'] - downtown_sd_lat
downtown_stops_df['lon_from_dt'] = downtown_stops_df['stop_lon'] - downtown_sd_lon

cs_f2 = sns.scatterplot(downtown_stops_df, x = 'lon_from_dt', y = 'lat_from_dt', hue = 'stop_agncy')
cs_f2.set_title("Distribution Relative to Downtown San Diego")

# adds red, dashed line indicating where Downtown San Diego is
cs_f2.axhline(0.0, color='red', linestyle='--')
cs_f2.axvline(0.0, color='red', linestyle='--')
cs_f2;

# %% [markdown]
# This scatter plot presents the spatial distribution of transit stops relative to downtown San Diego by measuring how far each stop’s latitude and longitude are from a central downtown coordinate. The red dashed lines represent the downtown reference point. Stops operated by MTS appear more concentrated closer to the downtown area, while NCTD stops appear farther north and along coastal regions. This spatial separation reflects the service areas of the two transit agencies. Examining transit stop locations relative to the city center helps provide spatial context that can help give context to crime or population distribution.

# %% [markdown]
# #### Exploring San Diego Neighborhood Crime Rates
#
# For this section, will we just focus on crime rates across San Diego Neighborhoods for one year, 2025. This is to simplify our analysis and focus on non-temporal relationships first.
#
# Because crime values are reported as rates per 1,000 residents, we can compare neighborhoods directly regardless of population size. We aim to understand the distribution of different crime categories and identify which offenses are most common across the city. These exploratory analyses help provide context for later comparisons between neighborhood crime patterns and transit activity.

# %% [markdown]
# ### Average Crime Rate by Offense Type

# %%
crime_df_2025 = pd.read_csv('data/02-processed/clean_nibrs_crime_rates_2025.csv')

avg_rates = crime_df_2025.drop(columns="Neighborhood").mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))

sns.barplot(x=avg_rates.values, y=avg_rates.index)

plt.title("Average Crime Rate by Offense Type")
plt.xlabel("Average Crime Rate per 1,000 Residents")
plt.ylabel("Crime Type");

# %% [markdown]
# This bar chart shows the average crime rate for each offense category across San Diego neighborhoods, measured as incidents per 1,000 residents. The visualization highlights that certain crimes occur much more frequently than others. Drug and narcotic violations, simple assault, and larceny have the highest average rates, indicating that these offenses are more common. Crimes like homicide, kidnapping, and gambling violations occur rarely. This pattern reflects broader crime trends where property crimes and lower-level offenses are more prevalent than severe violent crimes. Understanding which crimes are more common gives us useful context for looking at how neighborhood crime patterns  relate to things such as population activity and public transit accessibility.

# %% [markdown]
# #### Neighborhoods with Highest Total Crime Rates

# %%
crime_df_2025["total_crime_rate"] = crime_df_2025.drop(columns="Neighborhood").sum(axis=1)

top_crime = crime_df_2025.sort_values("total_crime_rate", ascending=False).head(10)

plt.figure(figsize=(10,6))

sns.barplot(data=top_crime,
            x="total_crime_rate",
            y="Neighborhood")

plt.title("Neighborhoods with Highest Total Crime Rates")
plt.xlabel("Total Crime Rate per 1,000 Residents")
plt.ylabel("Neighborhood");

# %% [markdown]
# This bar chart shows ten San Diego neighborhoods with the highest total crime rates per 1,000 residents. Mission Bay has a significantly higher crime rate than all other neighborhoods, followed by Qualcomm and Balboa Park. Gaslamp and Old Town also show relatively high crime levels compared to the rest of the city. Many of these neighborhoods are major tourist destinations or commercial districts with high foot traffic, which can contribute to increased opportunities for certain crimes like theft, vandalism, or drug-related offenses. This visualization highlights how crime distribution varies geographically and helps identify areas where higher activity levels may influence crime patterns.

# %% [markdown]
# #### Distribution of Major Crime Types Across Neighborhoods

# %%
selected_cols = [
    "Simple Assault",
    "Robbery",
    "Larceny",
    "Motor Vehicle Theft",
    "Vandalism",
    "Drug/Narcotic Offenses"
]

crime_subset = crime_df_2025[selected_cols]

plt.figure(figsize=(10,6))

sns.boxplot(data=crime_subset)

plt.ylim(0,50)

plt.title("Distribution of Major Crime Types Across San Diego Neighborhoods")
plt.ylabel("Crime Rate per 1,000 Residents")
plt.xticks(rotation=45);

# %% [markdown]
# This boxplot shows how crime rates vary across San Diego neighborhoods for major offense categories. Each box represents the distribution of crime rates per 1,000 residents. Crimes like larceny and vandalism display a wider spread, indicating greater variation between neighborhoods. Offenses such as robbery tend to remain relatively low across most areas. The presence of several outliers suggests that a small number of neighborhoods experience significantly higher crime rates than the rest of the city. This visualization highlights that crime is unevenly distributed across neighborhoods and that certain crime types show greater variability than others.

# %% [markdown]
# #### Takeaways from the relationship between neighborhoods and crime
# Overall, this exploratory analysis reveals that crime in San Diego neighborhoods varies significantly across both offense type and location. Some offenses, such as drug violations and larceny, occur more frequently than others, while serious crimes remain relatively rare. Additionally, crime rates appear concentrated in certain neighborhoods, particularly areas with high levels of tourism or commercial activity. These findings suggest that local activity patterns may influence crime rates. In the next stages of analysis, we will compare these crime patterns with public transit ridership and transit stop locations to investigate whether transit infrastructure is associated with differences in neighborhood crime levels.

# %% [markdown]
# ### Analyzing 2023-2025 Trolley Ridership Data
# In this section, we explore San Diego transit ridership patterns to understand when and where transit is used the most. This helps contextualize whether areas with higher transit usage may overlap with higher crime or higher stop density. We examine ridership distributions, temporal trends, and station-level differences.

# %% [markdown]
# #### How many stations serve each line?

# %%
clean_ridership_df = pd.read_csv('data/02-processed/cleaned_mts_trolley_ridership_data.csv')

color_map = {'Blue': 'tab:blue', 'Green': 'tab:green', 'Orange': 'tab:orange', 'Copper': 'tab:brown'}

line_counts = clean_ridership_df.groupby('Line')['Station'].nunique().reset_index()
ax = sns.barplot(line_counts, x='Line', y='Station', hue='Line', palette=color_map)
[ax.bar_label(c) for c in ax.containers]
plt.title('Number of Stations per Line')
plt.show()

# %% [markdown]
# The barplot displays the number of stations served by each line. We can see that the Blue line serves 33 stations, whereas the Copper line serves only 3 stations. While we expect that ridership activity scales with the number of stops, this information is highly important for further analyses. For any later comparisons using the trolley lines, including crime rates or socioeconomic geography, we will ensure that the numbers are not skewed by sheer size.

# %% [markdown]
# #### How many observations do we have per year?

# %%
ax = sns.countplot(clean_ridership_df, x='Year', color='darkgray')
ax.bar_label(ax.containers[0])
plt.title('Total Observations by Year')
plt.show()

# %% [markdown]
# This barplot shows the number of ridership observations per year to ensure that we understand the distribution of observations before later comparisons. As expected, there are a few observations for 2025 ($n_{2025}=80$), while there are many for 2024 ($n_{2024}=240$). Since the dataset included only one season of 2025 (spring), we know any ridership trends may reflect partial data collection rather than a decrease in ridership.

# %% [markdown]
# #### How is daily average ridership distributed?

# %%
sns.histplot(clean_ridership_df, x='Ridership', color='darkgray')
plt.title('Distribution of Ridership')
plt.show()

# %% [markdown]
# Above, we can see that the distribution of ridership is right-skewed with outliers in the 10,000s range. This indicates that there a few stations that have massive crowds, and the typical stop has low-to-medium traffic everyday. Rather than using median to accomodate this skew, we will continue using the mean since these numbers especially reflect crime rates and socioeconomic landscapes.

# %% [markdown]
# #### How does ridership vary between the transit lines?

# %%
sns.boxplot(clean_ridership_df, x='Line', y='Ridership', hue='Line', palette=color_map)
plt.title('Distribution of Ridership by Line')
plt.show()

# %% [markdown]
# For a better understanding of daily ridership activity, we plot ridership by trolley lines. We can see that the Blue line has the most outliers and that the Copper line has a small spread of daily activity. Furthermore, this boxplot reflects that of the Number of Stations per Line barplot. The spread of ridership activity positively scales with the number of stations served by a line.

# %% [markdown]
# #### How does passenger density by transit line change over time?

# %%
line_map = dict(zip(line_counts['Line'], line_counts['Station']))
clean_ridership_df['Ridership_scaled'] = clean_ridership_df['Ridership'] / clean_ridership_df['Line'].map(line_map)

sns.lineplot(clean_ridership_df, x='Year', y='Ridership_scaled',  hue='Line', palette=color_map, hue_order=['Copper', 'Orange', 'Blue', 'Green'], estimator=np.mean, errorbar=None, marker='o')
plt.xticks([2023, 2024, 2025])
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.))
plt.title('Yearly Mean Ridership by Line (2023-2025)')
plt.ylabel('Ridership (relative to Line)')
plt.show()

# %% [markdown]
# The final visualization for this dataset considers the information from the previous plots. Since we are interested in ridership activity, its fluctuation over time, and its relationship to crime, we need to look at how rider density changes yearly per line. By scaling ridership and taking the mean, we capture the typical number of passengers of each line. Although the Copper line has the smallest number of stations, it maintains more activity than the longer, more popular lines. Furthermore, the Blue, Orange, and Green lines all have consistent ridership density across the years. This establishes an important baseline moving onto analyses involving ridership, crime, and the socioeconomic landscape.

# %% [markdown]
# ### Looking into Socioeconmic data

# %% [markdown]
# This section uses the San Diego Equity dataset to provide socioeconomic context for transit usage. We focus on commuting behaviors (driving vs public transit vs walking/biking) and how these patterns change over time and across groups. This helps interpret whether transit access and adoption may vary by socioeconomic factors, which is important for our later comparisons with transit infrastructure and crime patterns.

# %% [markdown]
# #### What is the distribution of commuting methods in San Diego?

# %%
clean_equity_df = pd.read_csv("data/02-processed/clean_equity.csv")


# Filter the dataset to only include commuting-related indicators
# so we can analyze transportation patterns.
commute_df = clean_equity_df[
    clean_equity_df["indicator"] == "Commute Time and Method of Transportation"
]

relevant_categories = ['Worked at home', 'Total Private Motor Vehicle', 'Total Public Transport', 'Bicycle', 'Walked Only' ]
commute_df = commute_df[commute_df['category'].isin(relevant_categories)]
# Create a bar chart to visualize the distribution of different commute methods
plt.figure(figsize=(8,5))

sns.barplot(
    data=commute_df,
    x="category",
    y="percent",
)

plt.xticks(rotation=90)

plt.title("Distribution of Commute Methods")
plt.xlabel("Commute Method")
plt.ylabel("Percent")

plt.show()

# %% [markdown]
# The boxplot shows clear differences in the distribution of commuting methods across categories. Private motor vehicle use has the highest percentages and the widest variation, indicating that driving is the dominant commuting method. In contrast, public transportation, bicycling, and walking account for much smaller shares. (Total Public Transport= subway + bus + ferry + rail + etc). The relatively low share of public transportation suggests that transit systems such as the trolley may still have limited usage compared with private vehicle commuting. However this does not account for usage the trolley system receives for travelling to places other than one's workplace.

# %% [markdown]
# #### How has public transport's mode share changed from 2023 to 2025?

# %%
commute_df = clean_equity_df[
    clean_equity_df["indicator"] == "Commute Time and Method of Transportation"
]

# Select the total public transportation category
# This represents the overall share of commuters using public transit
transit_df = commute_df[
    commute_df["category"] == "Total Public Transport"
]

# Plot the trend over report years
plt.figure(figsize=(7,5))

sns.lineplot(
    data=transit_df,
    x="equity_report_year",
    y="percent",
    marker="o"
)

plt.title("Trend of Public Transportation Usage Over Time")
plt.xlabel("Report Year")
plt.ylabel("Percent of Commuters Using Public Transportation")

plt.show()

# %% [markdown]
# Public transit saw a slight decrease in usage from 2023 to 2025. The low proportion of public transportation usage indicates strong reliance on private vehicles. This pattern highlights the potential challenges for expanding public transit adoption and improving transportation equity.

# %% [markdown]
# ### Fully Merged Dataset Analysis
#
# After exploring each dataset individually, we now have some idea of how to connect it all together with our analysis of the fully merged dataset.
#
# In this section we will be exploring the connections between our datasets and testing whether or not there are any statistically significant relationships which will help us answer our research question: Is there an association between increased ridership at San Diego Trolley stations and nearby crime rates over time? Are these effects different across neighborhood socioeconomic contexts?

# %% [markdown]
# #### Exploration of Fully Merged Dataset

# %%
eda_df = pd.read_csv('data/02-processed/final_transit_crime_data_cleaned.csv')
c_lines = {'Blue':'tab:blue', 'Green':'tab:green', 'Orange':'tab:orange'}
crime_cols = ['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses']
eda_df['Total Crime'] = eda_df[crime_cols].sum(axis=1)

# %% [markdown]
# To begin, we'll explore crime rate by trolley line to identify general trends. This aggregation is easier to interpret than stops or neighborhoods while still maintaining a level of geographic context.

# %%
sns.lineplot(eda_df, x='Year', y='Total Crime', hue='Line', palette=c_lines, hue_order=['Green', 'Orange', 'Blue'], errorbar=None, marker='o')
plt.xticks([2023, 2025])
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.))
plt.title('Mean Total Crime per Year by Trolley Line');

# %%
crime_rate_by_line = eda_df.groupby('Line')[['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses']].mean()
sns.heatmap(crime_rate_by_line, annot=True, fmt='.1f', cmap='rocket_r')
plt.xticks(rotation=45)
plt.title('Average Crime Incidents by Trolley Line');

# %%
station_baseline = eda_df.groupby(['Station', 'Year', 'Season', 'Neighborhood'])[['Ridership', 'Total Crime']].mean().reset_index()
nbr_eda = station_baseline.groupby('Neighborhood')[['Ridership', 'Total Crime']].mean().reset_index()

sns.boxplot(nbr_eda, x='Total Crime', log_scale=False)
plt.title('Distribution of Crime Rate')
plt.xlabel('Crime Rate per 1,000 Residents')
plt.show()

nbr_eda_no_outlier = nbr_eda[nbr_eda['Total Crime'] < 1000]
sns.barplot(nbr_eda_no_outlier, y='Neighborhood', x='Total Crime', order=nbr_eda_no_outlier.sort_values('Total Crime', ascending=False)['Neighborhood'].values)
plt.xlabel('Crime Rate per 1,000 Residents')
plt.title(f'Crime Rates by Neighborhood (n={len(nbr_eda_no_outlier)} neighborhoods)');

# %%
outlier = nbr_eda['Total Crime'].argmax()
ax = sns.barplot(clean_crime_df.loc[clean_crime_df['Neighborhood'] == nbr_eda.loc[outlier, 'Neighborhood'], crime_cols], orient='v', estimator=np.mean, errorbar=None, palette='tab20')
[ax.bar_label(c) for c in ax.containers]
plt.xticks(rotation=45)
plt.xlabel('Crime Rate per 1,000 Residents')
plt.title(f"Outlier {nbr_eda.loc[outlier, 'Neighborhood'].title()} Crime Report");

# %% [markdown]
# ##### Addressing Qualcomm and Stand-out Neighborhoods
#
# The outlier of the "Qualcomm" neighborhood is referring to the area where Qualcomm stadium used to be. This area has a very low residential population but attracts many people to the area for sports games at the new Snapdragon arena. As a relatively low population area with lots of non-residents being attracted to it, "Qualcomm" can expect that crime would be attracted to it as well. But the metric we use, number of permanent residents in the area, falls way short of accounting for how many people set foot in the area in a day. Thus, the crime rate is FAR larger than other typical neighborhoods like Logan Heights or La Jolla.
#
# This reasoning extends somewhat to neighborhoods listed in the bar plot above Qualcomm's barplot as well. "Neighborhoods" like Mission Valley West, Old Town, and Petco Park attract far more tourism and commerce than most other neighborhoods and have less residential space. So, the actual population of these areas does not reflect how many people populate them on a daily basis. And as we just stated, this can make the crime rates seem catastrophically high, but in reality they are just not properly accounting for crime per person in the area.
#
# This is a good reminder that data can be misleading and doesn't always represent reality the way you want it to. It is important to apply domain knowledge and context to your analysis so you do not come to unreasonable conclusions like Qualcomm is a anarchical, crime-infested wasteland because the data indicates it has a total crime rate of over 1184 per 1000 residents.

# %%
map_df = eda_df.groupby(['Station', 'stop_lat', 'stop_lon'])[['Ridership', 'Total Crime']].mean().reset_index()

sns.scatterplot(map_df, x='stop_lon', y='stop_lat', size='Ridership', sizes=(40, 400), hue='Total Crime', alpha=0.85)
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.))
plt.locator_params(axis='both', nbins=7)
plt.title('Geographic Distribution of Ridership and Total Crime')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
    
xy_pos = {'Stadium Station':(-15, -15), 'Old Town':(-10, -15), '12th/Imperial':(-50, -15), 'San Ysidro':(-50, -10)}
for _, row in map_df[map_df['Station'].isin(xy_pos.keys())].iterrows():
    plt.annotate(row['Station'], (row['stop_lon'], row['stop_lat']), xytext=xy_pos[row['Station']], textcoords='offset points')

# %% [markdown]
# ### Statistical Analysis of Merged Dataset
#
# Now that we have thoroughly explored every dataset individually and collectively, we move onto statistical inference.

# %% [markdown]
# First, we collapse the data from trolley line to individual station. While exploding the data based on line let us simplify our EDA, this complicates statistical methods.

# %%
# Reset df
df = pd.read_csv('data/02-processed/final_transit_crime_data_cleaned.csv')

# Collapse dataset from line to station
df = df.groupby(['Station', 'Year', 'Season', 'Neighborhood'])[df.drop(columns=['Station', 'Year', 'Season', 'Neighborhood', 'Line']).columns].mean().reset_index()
df['Total Crime'] = df[crime_cols].sum(axis=1)
df.head()
# Out:
#                    Station  Year  Season Neighborhood  stop_lat   stop_lon  \
# 0            12th/Imperial  2023    Fall   PETCO PARK  32.70583 -117.15327
# 1            12th/Imperial  2023  Summer   PETCO PARK  32.70583 -117.15327
# 2            12th/Imperial  2025  Spring   PETCO PARK  32.70583 -117.15327
# 3  12th/Imperial (Bayside)  2023    Fall   PETCO PARK  32.70523 -117.15390
# 4  12th/Imperial (Bayside)  2023  Summer   PETCO PARK  32.70523 -117.15390
#
#    Ridership  Simple Assault  Robbery  Larceny  Motor Vehicle Theft  \
# 0    13184.0           64.40    15.50    35.20                 8.40
# 1    12936.0           64.40    15.50    35.20                 8.40
# 2    10330.0           59.63     3.58    20.87                 3.58
# 3     3002.0           64.40    15.50    35.20                 8.40
# 4     2763.0           64.40    15.50    35.20                 8.40
#
#    Vandalism  Drug/Narcotic Offenses  Self-Sufficiency Wage_Yes  \
# 0      34.60                   58.40                       30.3
# 1      34.60                   58.40                       30.3
# 2      28.62                  131.78                       55.6
# 3      34.60                   58.40                       30.3
# 4      34.60                   58.40                       30.3
#
#    Business Ownership_Minority  \
# 0                    39.133333
# 1                    39.133333
# 2                    42.666667
# 3                    39.133333
# 4                    39.133333
#
#    Commute Time and Method of Transportation_Total Private Motor Vehicle  \
# 0                                               80.1
# 1                                               80.1
# 2                                               78.0
# 3                                               80.1
# 4                                               80.1
#
#    English Language Learners_Level 1  Total Crime
# 0                          19.585714       216.50
# 1                          19.585714       216.50
# 2                          20.750000       248.06
# 3                          19.585714       216.50
# 4                          19.585714       216.50

# %%
feat = ['Year', 'Self-Sufficiency Wage_Yes', 'Business Ownership_Minority', 'Commute Time and Method of Transportation_Total Private Motor Vehicle', 'English Language Learners_Level 1']
adj_labels = [f.split()[0] for f in feat]
sns.heatmap(df[feat].corr(), annot=True, cmap='vlag_r', vmin=-1.0, vmax=1.0, xticklabels=adj_labels);

# %% [markdown]
# Because the equity indicators and year variable are perfectly correlated, we cannot perform analyses using these together without introducing multicollinearity. To address this, we will use the blue line indicator from before as a proxy for our socioeconomic contexts. This prevents double counting on stations which serve multiple lines and avoids multicollinearity by introducing many dummy variables.
#
# Although we can simply replace `Year` with any equity variable, using an indicator like blue line provides better spatial granularity and unique geographic signal. Note, however, we do not have available data on rider demographics that would potentially explain socioeconomic factors. *This is a limitation of the data.*

# %%
blue_line = [
    'UTC Station', 'Executive Drive', 'UCSD Health La Jolla', 'UCSD Central Campus', 'VA Medical Center',
    'Nobel Drive', 'Balboa Avenue', 'Clairemont Drive', 'Tecolote Road', 'Old Town', 'Washington St', 
    'Middletown', 'County Center/Little Italy', 'Santa Fe Depot', 'America Plaza', 'Civic Center', 
    'Fifth Ave', 'City College', 'Park/Market', 'Barrio Logan', 'Harborside', 'Pacific Fleet', '8th St', 
    '24th St', 'E St', 'H St', 'Palomar St', 'Palm Ave', 'Iris Ave', 'Beyer Blvd', 'San Ysidro', '12th/Imperial',
    '12th/Imperial (Bayside)'
]

df['Blue Line'] = df['Station'].isin(blue_line).astype(int)

# %%
# Checking for multicollinearity among our predictors
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

vif = df[['Ridership', 'Blue Line']].copy()
vif = pd.concat([vif, pd.get_dummies(df['Year'], drop_first=True, dtype=int)], axis=1)
vif = add_constant(vif)

vif_results = pd.DataFrame(index=vif.columns.astype(str).str.title())
vif_results['VIF'] = [variance_inflation_factor(vif.values, j) for j in range(len(vif.columns))]

display(vif_results.round(5))
# Out:
#                VIF
# Const      3.08054
# Ridership  1.14066
# Blue Line  1.13944
# 2025       1.00122

# %% [markdown]
# To ensure that the blue line proxy is not mathematically redundant or noisy, we use the Variance Inflation Factor (VIF) metric to measure variance attributed to collinearity with other predictors. The VIF scores for `Ridership`, `Blue Line`, and `Year (2025)` are all roughly ~1., suggesting minimal multicollinearity. Therefore, we can make reliable interpretations of each predictor in modeling, such as interpreting blue line results as socioeconomic contexts.

# %% [markdown]
# Now, we perform paired t-tests to see if there are any statistically significant shifts in crime or ridership between 2023 and 2025.

# %%
annual_crime = df.groupby(['Year', 'Station'])['Total Crime'].mean().reset_index()
annual_crime_df = annual_crime.pivot(index='Station', columns='Year', values='Total Crime').dropna()
ttest_crime = stats.ttest_rel(annual_crime_df[2023], annual_crime_df[2025])

annual_ridership = df.groupby(['Year', 'Station'])['Ridership'].mean().reset_index()
annual_ridership_df = annual_ridership.pivot(index='Station', columns='Year', values='Ridership').dropna()
ttest_rider = stats.ttest_rel(annual_ridership_df[2023], annual_ridership_df[2025])

diff = annual_ridership_df[2025] - annual_ridership_df[2023]
cohens_d = np.mean(diff) / np.std(diff, ddof=1)

display(pd.DataFrame({'p-value':[ttest_crime.pvalue, ttest_rider.pvalue], "Cohen's d":[np.nan, cohens_d]}, index=['Total Crime', 'Ridership']))
# Out:
#               p-value  Cohen's d
# Total Crime  0.157678        NaN
# Ridership    0.032631  -0.317788

# %% [markdown]
# As seen above, the paired t-tests yielded p-values of 0.158 for crime rates and 0.033 for ridership. At a standard significance level $(\alpha=0.05)$, these results suggest that annual total crime rate remains statistically constant from 2023 to 2025, while average ridership significantly decreased with a moderate effect size measure (-0.318). However, this decline may be a consequence of comparing a much larger timeframe (2023) to only a month (January 2025).
#
# Notably, this suggests that any significant results from modeling are not driven by any city-wide crime trends.

# %%
base_df = df[['Ridership', 'Year', 'Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses', 'Total Crime']]

crime_cols = ['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses', 'Total Crime']

sns.pairplot(base_df, x_vars=crime_cols, y_vars='Ridership');

# %%
# Editing the code above to exclude the top 2% of data (excludes outliers which are mostly represented by "neighborhoods"
# which have very low residency but high tourism, resulting in distorted crime rates)

crime_cols = ['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses', 'Total Crime']


filtered_df = base_df.copy()
for col in crime_cols:
    upper = filtered_df[col].quantile(0.98)
    filtered_df = filtered_df[filtered_df[col] <= upper]

sns.pairplot(filtered_df, x_vars=crime_cols, y_vars='Ridership');

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6), sharey=True)
sns.heatmap(base_df.corr(), annot=True, cmap='vlag_r', fmt='.1f', vmin=-1.0, vmax=1.0, ax=axs[0])
axs[0].set_title('Correlation Matrix for All Crime Reports')
sns.heatmap(filtered_df.corr(), annot=True, cmap='vlag_r', fmt='.1f', vmin=-1.0, vmax=1.0, ax=axs[1])
axs[1].set_title('Correlation Matrix (Excluding Top 2%)');

# %%
mdl_df = df.copy()

crime_cols = ['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses', 'Total Crime']

for col in crime_cols:
    upper = mdl_df[col].quantile(0.98)
    mdl_df = mdl_df[mdl_df[col] <= upper]

sns.boxplot(mdl_df[crime_cols])
plt.xticks(rotation=45);

# %%
lm1 = smf.ols('Q("Total Crime") ~ Ridership * C(Year)', data=mdl_df).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Q("Total Crime")   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     4.417
# Date:                Tue, 17 Mar 2026   Prob (F-statistic):            0.00545
# Time:                        05:49:10   Log-Likelihood:                -672.88
# No. Observations:                 131   AIC:                             1354.
# Df Residuals:                     127   BIC:                             1365.
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    40.7521      5.627      7.243      0.000      29.618      51.886
# C(Year)[T.2025]              11.0674      9.881      1.120      0.265      -8.486      30.621
# Ridership                     0.0060      0.002      3.533      0.001       0.003       0.009
# Ridership:C(Year)[T.2025]    -0.0081      0.004     -2.265      0.025      -0.015      -0.001
# ==============================================================================
# Omnibus:                       27.317   Durbin-Watson:                   0.635
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.912
# Skew:                           0.895   Prob(JB):                     1.96e-12
# Kurtosis:                       5.584   Cond. No.                     9.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
lm2 = smf.ols('Q("Total Crime") ~ Ridership * C(Year) + Ridership * Q("Blue Line")', data=mdl_df).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Q("Total Crime")   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     3.469
# Date:                Tue, 17 Mar 2026   Prob (F-statistic):            0.00571
# Time:                        05:49:10   Log-Likelihood:                -670.87
# No. Observations:                 131   AIC:                             1354.
# Df Residuals:                     125   BIC:                             1371.
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    58.2746     11.217      5.195      0.000      36.074      80.475
# C(Year)[T.2025]              10.3545      9.821      1.054      0.294      -9.083      29.792
# Ridership                    -0.0061      0.009     -0.644      0.521      -0.025       0.013
# Ridership:C(Year)[T.2025]    -0.0078      0.004     -2.204      0.029      -0.015      -0.001
# Q("Blue Line")              -24.1002     12.297     -1.960      0.052     -48.437       0.237
# Ridership:Q("Blue Line")      0.0130      0.010      1.370      0.173      -0.006       0.032
# ==============================================================================
# Omnibus:                       30.615   Durbin-Watson:                   0.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.739
# Skew:                           0.892   Prob(JB):                     1.32e-17
# Kurtosis:                       6.325   Cond. No.                     1.94e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.94e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
crime_cols = ['Simple Assault', 'Robbery', 'Larceny', 'Motor Vehicle Theft', 'Vandalism', 'Drug/Narcotic Offenses']

for c in crime_cols:
    frm = f'Q("{c}") ~ Ridership * C(Year) + Ridership * Q("Blue Line")'
    mdl = smf.ols(frm, data=mdl_df).fit()
    coeffs = pd.DataFrame(mdl.params).rename(columns={0:f'Coefficient'})
    pvals = pd.DataFrame(mdl.pvalues).rename(columns={0:f'P-value'})
    print(f'{c} (R-squared={mdl.rsquared:.3f}, R2-adjusted={mdl.rsquared_adj:.3f})')
    display(pd.concat([coeffs, pvals], axis=1).round(5))
    print()
# Out:
# Simple Assault (R-squared=0.213, R2-adjusted=0.182)
#                            Coefficient  P-value
# Intercept                      8.22185  0.00269
# C(Year)[T.2025]                1.70504  0.46954
# Ridership                      0.00094  0.67868
# Ridership:C(Year)[T.2025]     -0.00244  0.00463
# Q("Blue Line")                -3.13973  0.28807
# Ridership:Q("Blue Line")       0.00138  0.54459
# Robbery (R-squared=0.209, R2-adjusted=0.178)
#                            Coefficient  P-value
# Intercept                      3.04026  0.00004
# C(Year)[T.2025]               -0.29585  0.63697
# Ridership                     -0.00056  0.35672
# Ridership:C(Year)[T.2025]     -0.00055  0.01497
# Q("Blue Line")                -1.80956  0.02246
# Ridership:Q("Blue Line")       0.00110  0.07149
# Larceny (R-squared=0.144, R2-adjusted=0.109)
#                            Coefficient  P-value
# Intercept                     24.47116  0.00000
# C(Year)[T.2025]                3.73926  0.23575
# Ridership                     -0.00787  0.01022
# Ridership:C(Year)[T.2025]     -0.00145  0.19979
# Q("Blue Line")               -16.64630  0.00004
# Ridership:Q("Blue Line")       0.00876  0.00465
# Motor Vehicle Theft (R-squared=0.183, R2-adjusted=0.151)
#                            Coefficient  P-value
# Intercept                      8.82841  0.00000
# C(Year)[T.2025]               -3.54714  0.00056
# Ridership                     -0.00081  0.39947
# Ridership:C(Year)[T.2025]     -0.00028  0.44620
# Q("Blue Line")                -1.67310  0.18483
# Ridership:Q("Blue Line")       0.00089  0.36302
# Vandalism (R-squared=0.159, R2-adjusted=0.126)
#                            Coefficient  P-value
# Intercept                      9.56771  0.00000
# C(Year)[T.2025]                0.24257  0.85889
# Ridership                     -0.00082  0.53439
# Ridership:C(Year)[T.2025]     -0.00126  0.01128
# Q("Blue Line")                -3.92920  0.02283
# Ridership:Q("Blue Line")       0.00182  0.16928
# Drug/Narcotic Offenses (R-squared=0.118, R2-adjusted=0.083)
#                            Coefficient  P-value
# Intercept                      4.14524  0.32193
# C(Year)[T.2025]                8.51064  0.02130
# Ridership                      0.00304  0.38813
# Ridership:C(Year)[T.2025]     -0.00180  0.17228
# Q("Blue Line")                 3.09770  0.49909
# Ridership:Q("Blue Line")      -0.00092  0.79486

# %%
df.groupby('Year').agg({
    'Ridership':'mean', 'Simple Assault': 'sum', 'Robbery': 'sum', 'Larceny': 'sum',
    'Motor Vehicle Theft': 'sum', 'Vandalism': 'sum', 'Drug/Narcotic Offenses': 'sum', 
    'Self-Sufficiency Wage_Yes': 'max', 'Business Ownership_Minority': 'max', 
    'Commute Time and Method of Transportation_Total Private Motor Vehicle': 'max',
    'English Language Learners_Level 1': 'max'
})
# Out:
#         Ridership  Simple Assault  Robbery  Larceny  Motor Vehicle Theft  \
# Year
# 2023  2093.104167         1127.40    289.0  1888.60              1274.40
# 2025  1914.375000         1065.35     79.9  1015.09               182.02
#
#       Vandalism  Drug/Narcotic Offenses  Self-Sufficiency Wage_Yes  \
# Year
# 2023    1127.00                 1849.60                       30.3
# 2025     390.14                 1694.18                       55.6
#
#       Business Ownership_Minority  \
# Year
# 2023                    39.133333
# 2025                    42.666667
#
#       Commute Time and Method of Transportation_Total Private Motor Vehicle  \
# Year
# 2023                                               80.1
# 2025                                               78.0
#
#       English Language Learners_Level 1
# Year
# 2023                          19.585714
# 2025                          20.750000

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [x] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Our project uses publicly available ridership and police-reported crime datasets, both of which are subject to systemic collection biases. Crime data reflected reported incidents rather than absolute true crime occurence and the accuracy of reports may vary across neighborhoods due to diffences in policing intensity, community trust in law enforcement and other factors. Ridership data may also overrepresent frequent riders rather than number of separate individuals. To address these concerns, we plan to be midful of these limitations when interpreting results, consider normalization of our data, and avoid drawing strong causal and opinionated conclussions from raw counts alone.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [x] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  - [x] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  - [x] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > While our analysis is quantitative, we recognize that our project may imply a sentiment towards the transit system, local communities, commuters and neighborhoods. To reduce potential blindspots, we plan to incorporate a wide range of relevant datasets where available, such as ridership patterns, crime statistics, and neighborhood-level socioeconomic indicators.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We are aware that dataset bias may arise from uneven data coverage since some trolley stations are more recently built than others, imbalanced station activity levels, and other variables. To mitigate these issues, we plan to incorporate relevant variables, test altervative models, and examine whether results are sensitive to different assumptions. This allow us to better assess the persuasivenees of observed patterns and reduce the risk of misleading conclusions.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > When presenting results, we aim to design visualizations that accurately and transparently our data and analysis. This includes using consistent axis scales across comparable plots, avoiding visual distortions that could create exaggerated or misleading trends. Clearly labeling units and time ranges is also important to keep authenticity. In addition, using different plots and graphs to represent complex patterns rather than descriptive statistics to avoid oversimplyfying is something we should consider as well.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > To support the reproducibility and transparency of our project, we plan to document our data, analysis and models in every step in a clear and organized manner. Code and intermediate outputs will be well recorded to allow others to rretrace the analysis pipeline if needed. This can help us ensure that potential errors can be identified easily and results can be tested or extended in later stages of our project.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > Our analysis may vary across neighborhoods with different socioeconomic characteristics, which could lead to misleading interpretations of results. We can examine results across different  subgroups. By comparing patterns across these groups, we can better understand whether observed relationships between ridership and crime differ systematically by context. This subgroup-based perspective helps us interpret findings more carefully and reduces the risk of drawing conclusions that may disproportionately reflect only certain groups.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We are aware that the choice of evalustion metics can influence how results are interpreted. Rather than relying on a single measure, we plan to explore multiple complementary metrics, such as crime counts, normalized crime rates, ridership growth percentages, and other relevant statistics. Considering multiple perspectives allows for a more informed understanding of our research question.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > To address this concers, we can prioritize interpretability when selecting analytical models and presenting results. Model outputs will be explained in understandable language and terms. This helps ensure that findings can be meaningfully interpreted by non-technical audiences and supports transparent communication of analytical outcomes.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will clearly commubicate the limitations of this study, including observational nature of the data, potential reporting biases, the presence of unmeasured confounding variables and that we cannot establish causal relationships in our project. For example, we acknowledge that reported crime rate does not equal absolute true crime occurence.
#
# ### E. Deployment
#  - [x] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  - [x] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary？
#
# > It is important to be able to revise or modify an analysis approach if issues are identifies. If problematic patterns, misleading results or unintended interpretations emerge during the project, we can adjust model specifications, go back and trace our documented analysis and codes to correct the errors or remove certain analysis from the final report. By doing that, we intend to prevent the presentation of results that may be inaccurate or potentially harmful.
#
#  - [x] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > The findings from this project could be misinterpreted or used in unintended ways, such as reinforcing negative stereotypes about the transit system or certain neighborhoods. To reduce this risk, we plan to carefully frame results, avoid opinionated conclusions, and emphasize contextual factors and limitations.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
